# %%
# !pip install pytchat
# Out:
# ...
#      |████████████████████████████████| 69 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.2 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 77 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.8 MB/s
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pytchat
chat = pytchat.create(video_id="oTSzxLvoEJE")  # แม้ว่ารายการจบแล้ว chat ก็จะยังขึ้นมา ==>ไปเอา video_id= มาจาก ลิ้งตรงหลัง v=........

live = []
with open('drive/MyDrive/data/source1.txt', 'w') as f:
    while chat.is_alive():
        for c in chat.get().sync_items():
            live +=
            print(f"{c.datetime} [{c.author.name}]- {c.message}")
            
            f.write(live)
            # f.write(f"{c.datetime} [{c.author.name}]- {c.message}")
# Out:
# 2021-08-14 01:59:36 [วิศวะ ชูชื่น]- 1
# 2021-08-14 01:59:45 [Thanachot Saengvimarn]- 3
# 2021-08-14 01:59:50 [Montip Auntum]- สวัสดีค่ะ
# 2021-08-14 02:00:08 [Supavadee Dishayabou]- สวัสดีค่ะ
# 2021-08-14 02:00:39 [สมมาตร สงคราม]- สวัสดีค่ะ
# 2021-08-14 02:01:35 [Aisvivo5G Ais]- สวัสดีครับ
# 2021-08-14 02:03:37 [Montip Auntum]- 100วันพีคสุดถ้าวัคซีนมาแบบเลศนัยต้องติด35ล้านคน
# 2021-08-14 02:04:08 [Gost]- คนไม่เก่งคิด ไม่เก่งค้า ไม่เก่งภาษา ไม่เก่งเศรษฐกิจ(ยิ่งอยู่นาน) ยิ่งวิกฤต ยิ่งวิปริต ไม่เชื่อ ! คอยดู.???
# 2021-08-14 02:05:03 [ธีรพัฒน์ ตั้งใจ]- แปลว่ามั่วครับ
# 2021-08-14 02:05:39 [svpzazmrna]- เอาเป็นเก่งเรื่องไรบ้างดีกว่าครับ ตอบสั้นหน่อย
# 2021-08-14 02:05:43 [Phan Punta]- ล็อกดาวน์เสียหายสองเด้งเชื้อผู้ติดเชื้อก็ยังพุ่ง และความเสียหายทางเศรษฐกิจการค้าการขาย
# 2021-08-14 02:06:00 [Montip Auntum]- ไม่เกี่ยวข้องก็จะเย็บปากไว้แต่คนไทยทุกคนมรผลกระทบด้วย
# ...

# %% [markdown]
# ## Lab 2 tweeter

# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

class listener(StreamListener):
    
    def on_data(self, data):
      	print (data.encode().decode('unicode_escape'))
      	return True
    
    def on_error(self, status):
        print (status)

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["popcat"])
